# %% [markdown]
# ### **Bubble Sort**
# ![Bubble Sort](https://www.computersciencebytes.com/wp-content/uploads/2016/10/bubble_sort.png)

# %%
def bubbleSort(arr):
    n = len(arr)
    step = 1
    for i in range(n-1):
        for j in range(0, n-i-1):
            print("step: ", step)
            step = step + 1
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# %%
array = [4,6, 7, 9]
bubbleSort(array)
print(array)
# Out:
# step:  1
# step:  2
# step:  3
# step:  4
# step:  5
# step:  6
# [4, 6, 7, 9]

# %%
def bubbleSort_optimize(arr):
    n = len(arr)
    step = 1
    for i in range(n-1):
        swapped = False
        for j in range(0, n-i-1):
            print("step: ", step)
            step = step + 1
            if arr[j] > arr[j + 1]:
                swapped = True
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
        if not swapped:
            return

# %%
array = [4,6, 7, 9]
bubbleSort_optimize(array)
print(array)
# Out:
# step:  1
# step:  2
# step:  3
# [4, 6, 7, 9]

# %%
def addUp(n):
    sum = 0
    for i in range(1, n+1):
        print("step ", i)
        sum = sum + i
    return sum

# %%
n = 10
print(addUp(n))
# Out:
# step  1
# step  2
# step  3
# step  4
# step  5
# step  6
# step  7
# step  8
# step  9
# step  10
# 55

# %%
def addUp(n):
    sum = n + 1
    sum = sum  * n
    sum = sum / 2
    return sum
    # return n * (n+1) / 2

# %%
n = 10
print(addUp(n))
# Out:
# 55.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the data
x = np.linspace(1, 100, 100)  # Represents the size of the input data (n)
y_n = x  # O(n) linear time
y_log_n = np.log2(x)  # O(log n) logarithmic time
y_n_log_n = x * np.log2(x)  # O(n log n) quasilinear time
y_n_square = x**2  # O(n^2) quadratic time

# Create the plot
plt.plot(x, y_n, label='O(n)')
plt.plot(x, y_log_n, label='O(log n)')
plt.plot(x, y_n_log_n, label='O(n log n)')
plt.plot(x, y_n_square, label='O(n^2)')

# Set the title and axis labels
plt.title('Time Complexity')
plt.xlabel('Input size (n)')
plt.ylabel('Time (steps)')

# Add a legend
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Binary Search**
# ![Image](https://miro.medium.com/v2/resize:fit:898/1*0OJ3eF9eO3FlPl5A_RtCSw.png)

# %%
# Python3 code to implement iterative Binary
# Search.

# It returns location of x in given array arr
def binarySearch(list, low, high, x):
    while low <= high:
        mid = low + (high - low) // 20
        # Check if x is present at mid
        if arr[mid] == x:
            return mid
        # If x is greater, ignore left half
        elif arr[mid] < x:
            low = mid + 1
        # If x is smaller, ignore right half
        else:
            high = mid - 1
    # If we reach here, then the element
    # was not present
    return -1


# Driver Code
if __name__ == '__main__':
    arr = [2, 3, 4, 10, 40]
    x = 10
    # Function call
    result = binarySearch(arr, 0, len(arr)-1, x)
    if result != -1:
        print("Element is present at index", result)
    else:
        print("Element is not present in array")
# Out:
# Element is present at index 3

# %%
def binary_search(list_data, search_value):
  low = 0
  high = len(list_data) - 1
  while low <= high:
    mid = (low + high) // 2
    if list_data[mid] == search_value:
      return mid
    elif list_data[mid] < search_value:
      low = mid + 1
    else:
      high = mid - 1
  return -1

numbers = [2, 3, 4, 10, 40]
search_value = 10
result = binary_search(numbers, search_value)
if result != -1:
  print("Element is present at index", result)
else:
  print("Element is not present in array")
# Out:
# Element is present at index 3

# %%
def binarySearchRecursive(list_data, low, high, search_value):
    if high >= low:

        mid = low + (high - low) // 2

        if list_data[mid] == search_value:
            return mid

        elif list_data[mid] > search_value:
            return binarySearchRecursive(list_data, low, mid-1, search_value)

        else:
            return binarySearchRecursive(list_data, mid + 1, high, search_value)

    else:
        return -1

# %%
numbers = [2, 3, 4, 10, 40]
search_value = 10
result = binarySearchRecursive(numbers, 0, len(numbers)-1, search_value)
if result != -1:
  print("Element is present at index", result)
else:
  print("Element is not present in array")
# Out:
# Element is present at index 3

# %%
def f(x):
    return x**2 - 1

def binary_search_min(f, a, b, tol=1e-7): # tolerance
    
    print("left \t\t right \t\t middle")
    while b - a > tol:
        mid = (a + b) / 2
        print("%.10f \t %.10f \t %.10f" %  (a,  b, mid))
        left_mid = mid - tol
        right_mid = mid + tol

        f_left_mid = f(left_mid)
        f_right_mid = f(right_mid)

        if f_left_mid < f_right_mid:
            b = mid
        else:
            a = mid

    return (a + b) / 2

# Example usage
a = -8  # starting point of interval
b = 10   # ending point of interval
minimum_x = binary_search_min(f, a, b)
minimum_f = f(minimum_x)

print("The minimum value of f(x) = x^2 - 1 is at x =", minimum_x)
print("The minimum value of the function is f(x) =", minimum_f)
# Out:
# left 		 right 		 middle
# -8.0000000000 	 10.0000000000 	 1.0000000000
# -8.0000000000 	 1.0000000000 	 -3.5000000000
# -3.5000000000 	 1.0000000000 	 -1.2500000000
# -1.2500000000 	 1.0000000000 	 -0.1250000000
# -0.1250000000 	 1.0000000000 	 0.4375000000
# -0.1250000000 	 0.4375000000 	 0.1562500000
# -0.1250000000 	 0.1562500000 	 0.0156250000
# -0.1250000000 	 0.0156250000 	 -0.0546875000
# -0.0546875000 	 0.0156250000 	 -0.0195312500
# -0.0195312500 	 0.0156250000 	 -0.0019531250
# -0.0019531250 	 0.0156250000 	 0.0068359375
# -0.0019531250 	 0.0068359375 	 0.0024414062
# -0.0019531250 	 0.0024414062 	 0.0002441406
# -0.0019531250 	 0.0002441406 	 -0.0008544922
# -0.0008544922 	 0.0002441406 	 -0.0003051758
# -0.0003051758 	 0.0002441406 	 -0.0000305176
# -0.0000305176 	 0.0002441406 	 0.0001068115
# -0.0000305176 	 0.0001068115 	 0.0000381470
# -0.0000305176 	 0.0000381470 	 0.0000038147
# -0.0000305176 	 0.0000038147 	 -0.0000133514
# -0.0000133514 	 0.0000038147 	 -0.0000047684
# -0.0000047684 	 0.0000038147 	 -0.0000004768
# -0.0000004768 	 0.0000038147 	 0.0000016689
# -0.0000004768 	 0.0000016689 	 0.0000005960
# -0.0000004768 	 0.0000005960 	 0.0000000596
# -0.0000004768 	 0.0000000596 	 -0.0000002086
# -0.0000002086 	 0.0000000596 	 -0.0000000745
# -0.0000000745 	 0.0000000596 	 -0.0000000075
# The minimum value of f(x) = x^2 - 1 is at x = 2.60770320892334e-08
# The minimum value of the function is f(x) = -0.9999999999999993

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def f(x):
    return x**2 - 1

# Generate x values
x = np.linspace(-8, 10, 400)
# Compute f(x) values
y = f(x)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='$f(x) = x^2 - 1$')

# Add titles and labels
plt.title('Plot of $f(x) = x^2 - 1$')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()

# Show the plot
plt.show()
